# %%
# for google colab
from google.colab import drive
# mount your Google Drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# for google colab
# copy all files from "Adaboost" directory in Google drive to current directory
# !cp -r ./gdrive/MyDrive/Adaboost/* .

# %%
import dataset
import adaboost
import utils
import detection
import matplotlib.pyplot as plt
from importlib import reload

# %% [markdown]
# ### Part 1
# Implement loadImages function in dataset.py and test the following code

# %%
print('Loading images')
trainData = dataset.loadImages('data/train')
print(f'The number of training samples loaded: {len(trainData)}')
testData = dataset.loadImages('data/test')
print(f'The number of test samples loaded: {len(testData)}')

print('Show the first and last images of training dataset')
fig, ax = plt.subplots(1, 2)
ax[0].axis('off')
ax[0].set_title('Car')
ax[0].imshow(trainData[1][0], cmap='gray')
ax[1].axis('off')
ax[1].set_title('Non car')
ax[1].imshow(trainData[-1][0], cmap='gray')
plt.show()
# Out:
# Loading images
# The number of training samples loaded: 600
# The number of test samples loaded: 600
# Show the first and last images of training dataset

# %% [markdown]
# ### Part 2
# Implement selectBest function in adaboost.py and test the following code.

# %%
adaboost = reload(adaboost)

# %%
print('Start training your classifier')
clf = adaboost.Adaboost(T=5)
clf.train(trainData)

print('\nEvaluate your classifier with training dataset')
utils.evaluate(clf, trainData)

print('\nEvaluate your classifier with test dataset')
utils.evaluate(clf, testData)
# Out:
# Start training your classifier
# Computing integral images
# Building features
# (16, 36)
# Applying features to dataset
# applying
# len(features)=134946, len(iis)=600
# applied 0 features
# applied 1000 features
# applied 2000 features
# applied 3000 features
# applied 4000 features
# applied 5000 features
# applied 6000 features
# applied 7000 features
# applied 8000 features
# applied 9000 features
# applied 10000 features
# applied 11000 features
# applied 12000 features
# applied 13000 features
# applied 14000 features
# applied 15000 features
# applied 16000 features
# applied 17000 features
# applied 18000 features
# applied 19000 features
# applied 20000 features
# applied 21000 features
# applied 22000 features
# applied 23000 features
# applied 24000 features
# applied 25000 features
# applied 26000 features
# applied 27000 features
# applied 28000 features
# applied 29000 features
# applied 30000 features
# applied 31000 features
# applied 32000 features
# applied 33000 features
# applied 34000 features
# applied 35000 features
# applied 36000 features
# applied 37000 features
# applied 38000 features
# applied 39000 features
# applied 40000 features
# applied 41000 features
# applied 42000 features
# applied 43000 features
# applied 44000 features
# applied 45000 features
# applied 46000 features
# applied 47000 features
# applied 48000 features
# applied 49000 features
# applied 50000 features
# applied 51000 features
# applied 52000 features
# applied 53000 features
# applied 54000 features
# applied 55000 features
# applied 56000 features
# applied 57000 features
# applied 58000 features
# applied 59000 features
# applied 60000 features
# applied 61000 features
# applied 62000 features
# applied 63000 features
# applied 64000 features
# applied 65000 features
# applied 66000 features
# applied 67000 features
# applied 68000 features
# applied 69000 features
# applied 70000 features
# applied 71000 features
# applied 72000 features
# applied 73000 features
# applied 74000 features
# applied 75000 features
# applied 76000 features
# applied 77000 features
# applied 78000 features
# applied 79000 features
# applied 80000 features
# applied 81000 features
# applied 82000 features
# applied 83000 features
# applied 84000 features
# applied 85000 features
# applied 86000 features
# applied 87000 features
# applied 88000 features
# applied 89000 features
# applied 90000 features
# applied 91000 features
# applied 92000 features
# applied 93000 features
# applied 94000 features
# applied 95000 features
# applied 96000 features
# applied 97000 features
# applied 98000 features
# applied 99000 features
# applied 100000 features
# applied 101000 features
# applied 102000 features
# applied 103000 features
# applied 104000 features
# applied 105000 features
# applied 106000 features
# applied 107000 features
# applied 108000 features
# applied 109000 features
# applied 110000 features
# applied 111000 features
# applied 112000 features
# applied 113000 features
# applied 114000 features
# applied 115000 features
# applied 116000 features
# applied 117000 features
# applied 118000 features
# applied 119000 features
# applied 120000 features
# applied 121000 features
# applied 122000 features
# applied 123000 features
# applied 124000 features
# applied 125000 features
# applied 126000 features
# applied 127000 features
# applied 128000 features
# applied 129000 features
# applied 130000 features
# applied 131000 features
# applied 132000 features
# applied 133000 features
# applied 134000 features
# out of applying
# Selecting best features
# Selected 13495 potential features
# Initialize weights
# Run No. of Iteration: 1
# Trained 1000 classifiers out of 13495
# Trained 2000 classifiers out of 13495
# Trained 3000 classifiers out of 13495
# Trained 4000 classifiers out of 13495
# Trained 5000 classifiers out of 13495
# Trained 6000 classifiers out of 13495
# Trained 7000 classifiers out of 13495
# Trained 8000 classifiers out of 13495
# Trained 9000 classifiers out of 13495
# Trained 10000 classifiers out of 13495
# Trained 11000 classifiers out of 13495
# Trained 12000 classifiers out of 13495
# Trained 13000 classifiers out of 13495
# Chose classifier: Weak Clf (threshold=438, polarity=-1, Haar feature (positive regions=[RectangleRegion(9, 3, 9, 9)], negative regions=[RectangleRegion(0, 3, 9, 9)]) with accuracy: 532.000000 and alpha: 5.371249
# Run No. of Iteration: 2
# Trained 1000 classifiers out of 13495
# Trained 2000 classifiers out of 13495
# Trained 3000 classifiers out of 13495
# Trained 4000 classifiers out of 13495
# Trained 5000 classifiers out of 13495
# Trained 6000 classifiers out of 13495
# Trained 7000 classifiers out of 13495
# Trained 8000 classifiers out of 13495
# Trained 9000 classifiers out of 13495
# Trained 10000 classifiers out of 13495
# Trained 11000 classifiers out of 13495
# Trained 12000 classifiers out of 13495
# Trained 13000 classifiers out of 13495
# Chose classifier: Weak Clf (threshold=75, polarity=1, Haar feature (positive regions=[RectangleRegion(32, 3, 1, 4)], negative regions=[RectangleRegion(31, 3, 1, 4)]) with accuracy: 427.000000 and alpha: 7.918889
# Run No. of Iteration: 3
# Trained 1000 classifiers out of 13495
# Trained 2000 classifiers out of 13495
# Trained 3000 classifiers out of 13495
# Trained 4000 classifiers out of 13495
# Trained 5000 classifiers out of 13495
# Trained 6000 classifiers out of 13495
# Trained 7000 classifiers out of 13495
# Trained 8000 classifiers out of 13495
# Trained 9000 classifiers out of 13495
# Trained 10000 classifiers out of 13495
# Trained 11000 classifiers out of 13495
# Trained 12000 classifiers out of 13495
# Trained 13000 classifiers out of 13495
# Chose classifier: Weak Clf (threshold=944, polarity=-1, Haar feature (positive regions=[RectangleRegion(14, 4, 21, 5)], negative regions=[RectangleRegion(14, 9, 21, 5)]) with accuracy: 487.000000 and alpha: 10.211042
# Run No. of Iteration: 4
# Trained 1000 classifiers out of 13495
# Trained 2000 classifiers out of 13495
# Trained 3000 classifiers out of 13495
# Trained 4000 classifiers out of 13495
# Trained 5000 classifiers out of 13495
# Trained 6000 classifiers out of 13495
# Trained 7000 classifiers out of 13495
# Trained 8000 classifiers out of 13495
# Trained 9000 classifiers out of 13495
# Trained 10000 classifiers out of 13495
# Trained 11000 classifiers out of 13495
# Trained 12000 classifiers out of 13495
# Trained 13000 classifiers out of 13495
# Chose classifier: Weak Clf (threshold=147, polarity=1, Haar feature (positive regions=[RectangleRegion(32, 3, 3, 2)], negative regions=[RectangleRegion(29, 3, 3, 2)]) with accuracy: 412.000000 and alpha: 12.146634
# Run No. of Iteration: 5
# Trained 1000 classifiers out of 13495
# Trained 2000 classifiers out of 13495
# Trained 3000 classifiers out of 13495
# Trained 4000 classifiers out of 13495
# Trained 5000 classifiers out of 13495
# Trained 6000 classifiers out of 13495
# Trained 7000 classifiers out of 13495
# Trained 8000 classifiers out of 13495
# Trained 9000 classifiers out of 13495
# Trained 10000 classifiers out of 13495
# Trained 11000 classifiers out of 13495
# Trained 12000 classifiers out of 13495
# Trained 13000 classifiers out of 13495
# Chose classifier: Weak Clf (threshold=585, polarity=-1, Haar feature (positive regions=[RectangleRegion(11, 1, 11, 13)], negative regions=[RectangleRegion(0, 1, 11, 13)]) with accuracy: 525.000000 and alpha: 9.682751
#
# Evaluate your classifier with training dataset
# False Positive Rate: 1/300 (0.003333)
# False Negative Rate: 26/300 (0.086667)
# Accuracy: 573/600 (0.955000)
#
# Evaluate your classifier with test dataset
# False Positive Rate: 7/300 (0.023333)
# False Negative Rate: 34/300 (0.113333)
# Accuracy: 559/600 (0.931667)

# %% [markdown]
# ### Part 3
# Modify difference values at parameter T of the Adaboost algorithm at Part 2. And find better results. Please test value 1~10 at least.

# %% [markdown]
# ### Part 4
# Implement detect function in detection.py and test the following code.

# %%
detection = reload(detection)

# %%
print('\nUse our classifier on video.gif to get the temporal parking spaces occupation informations')
detection.detect('data/detect/detectData.txt', clf)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# for google colab
# REMEMBER to execute this line once you've modified any .py code!
# Save the .py code you have modified to your Google Drive
# !cp ./*.py ./gdrive/MyDrive/Adaboost/
# !cp ./*.txt ./gdrive/MyDrive/Adaboost/
